# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2022_totals.html')

# %%
len(df)
# Out:
# 1

# %%
type(df)
# Out:
# list

# %%
df[0]
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1   Precious Achiuwa   C  22  TOR  73  28  1725  265   603  ...  .595
# 1      2       Steven Adams   C  28  MEM  76  75  1999  210   384  ...  .543
# 2      3        Bam Adebayo   C  24  MIA  56  56  1825  406   729  ...  .753
# 3      4       Santi Aldama  PF  21  MEM  32   0   360   53   132  ...  .625
# 4      5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252   458  ...  .873
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 837  601     Thaddeus Young  PF  33  TOR  26   0   475   67   144  ...  .481
# 838  602         Trae Young  PG  23  ATL  76  76  2652  711  1544  ...  .904
# 839  603     Omer Yurtseven   C  23  MIA  56  12   706  130   247  ...  .623
# 840  604        Cody Zeller   C  29  POR  27   0   355   51    90  ...  .776
# 841  605        Ivica Zubac   C  24  LAC  76  76  1852  310   495  ...  .727
#
#      ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0    146  327  473   82  37  41   84  151   664
# 1    349  411  760  256  65  60  115  153   528
# 2    137  427  564  190  80  44  148  171  1068
# 3     33   54   87   21   6  10   16   36   132
# 4     73  185  258   42  14  47   44   78   607
# ..   ...  ...  ...  ...  ..  ..  ...  ...   ...
# 837   40   75  115   45  31  11   22   43   164
# 838   50  234  284  737  72   7  303  128  2155
# 839   85  209  294   49  17  20   41   84   299
# 840   50   75  125   22   8   6   19   56   140
# 841  217  427  644  120  36  77  114  203   785
#
# [842 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk            Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0  1  Precious Achiuwa   C  22  TOR  73  28  1725  265  603  ...  .595  146
# 1  2      Steven Adams   C  28  MEM  76  75  1999  210  384  ...  .543  349
# 2  3       Bam Adebayo   C  24  MIA  56  56  1825  406  729  ...  .753  137
#
#    DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  327  473   82  37  41   84  151   664
# 1  411  760  256  65  60  115  153   528
# 2  427  564  190  80  44  148  171  1068
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Player','Age']]
# Out:
#                 Player Age
# 0     Precious Achiuwa  22
# 1         Steven Adams  28
# 2          Bam Adebayo  24
# 3         Santi Aldama  21
# 4    LaMarcus Aldridge  36
# ..                 ...  ..
# 837     Thaddeus Young  33
# 838         Trae Young  23
# 839     Omer Yurtseven  23
# 840        Cody Zeller  29
# 841        Ivica Zubac  24
#
# [842 rows x 2 columns]

# %%
df1.to_csv('NBA.csv', index = False)

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 3

# %%
l[0].to_csv('cricket.csv', index = False)

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Rajkot, 3rd T20I, Jan 7, ...
# 2  India v Sri Lanka at Pune, 2nd T20I, Jan 5, 20...
# 3  India v Sri Lanka at Wankhede, 1st T20I, Jan 3...

# %%
d ="""
{"name" : "Hero Sun" , 
"email id " : "herosun@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"platform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
import json

# %%
json.loads(d)
# Out:
# {'name': 'Hero Sun',
#  'email id ': 'herosun@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'platform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
j = json.loads(d)

# %%
type(j)
# Out:
# dict

# %%
pd.DataFrame(j)
# Out:
#        name          email id  tech    platform
# 0  Hero Sun  herosun@gmail.com   ML  techneuron
# 1  Hero Sun  herosun@gmail.com   DL  kidsneuron
# 2  Hero Sun  herosun@gmail.com   CV     ineuron

# %%
j['name']
# Out:
# 'Hero Sun'

# %%
pd.DataFrame(j['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# tcuTemperatureAverage              D
# coolantMin                         D
# coolantMax                         D
# coolantAverage                     D
# packetStartLocal                   D
# tripStartLocal                     D
# milIndicator                       D
# monitorsNotReady                   D
# imei                               D
# gatewayTs                          D
# diagnosticTroubleCodeData          D
# diagnosticPidData                  D
# iwrapVer                           D
# sourceSystem                       D
# configVer                          D
# oemName                            D
# unitType                           D
# cpVer                              D
# igpsVer                            D
# messageType                        D
# pomVer                             D
# headerVer                          D
# timestamp                          D
# deviceType                         D
# visorVer                           D
# transactionId                      D
# deviceSerialNo                     D
# subOrganization                    D
# organization                       D
# operation                          D
#
#                                                                         data  \
# checkEngineLightFlag                                                       F
# batteryVoltageStableTime                                                   0
# batteryVoltageStable                                                       0
# batteryVoltageOff                                                      12.42
# batteryCrankParamTN                                                    -0.08
# batteryCrankParamVN                                                     0.00
# batteryCrankParamTP                                                    -0.08
# batteryCrankParamVP                                                     0.00
# batteryCrankParamTT                                                 -0.00008
# batteryCrankParamV0                                                     0.00
# batteryVoltageMaxOn                                                    13.05
# batteryVoltageMinOn                                                    12.97
# batteryVoltageMaxOff                                                   12.46
# batteryVoltageMinOff                                                   12.36
# batteryVoltageOnAverage                                                13.02
# engineLoadMax                                                             84
# engineLoadAverage                                                      39.98
# rpmMax                                                                  3487
# rpmAverage                                                           1431.29
# gpsSpeedAverage                                                        21.99
# vssMax                                                                 53.44
# vssAverage                                                             23.06
# tcuTemperatureMin                                                      82.40
# tcuTemperatureMax                                                     109.40
# tcuTemperatureAverage                                                 104.87
# coolantMin                                                            158.00
# coolantMax                                                            188.60
# coolantAverage                                                        180.20
# packetStartLocal                                               1508143346000
# tripStartLocal                                                 1508143346000
# milIndicator                                                               F
# monitorsNotReady                                                           0
# imei                                                                60DF5417
# gatewayTs                                                      1515613306592
# diagnosticTroubleCodeData                                                 []
# diagnosticPidData          [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                 NaN
# sourceSystem                                                             NaN
# configVer                                                                NaN
# oemName                                                                  NaN
# unitType                                                                 NaN
# cpVer                                                                    NaN
# igpsVer                                                                  NaN
# messageType                                                              NaN
# pomVer                                                                   NaN
# headerVer                                                                NaN
# timestamp                                                                NaN
# deviceType                                                               NaN
# visorVer                                                                 NaN
# transactionId                                                            NaN
# deviceSerialNo                                                           NaN
# subOrganization                                                          NaN
# organization                                                             NaN
# operation                                                                NaN
#
#                                                          header
# checkEngineLightFlag                                        NaN
# batteryVoltageStableTime                                    NaN
# batteryVoltageStable                                        NaN
# batteryVoltageOff                                           NaN
# batteryCrankParamTN                                         NaN
# batteryCrankParamVN                                         NaN
# batteryCrankParamTP                                         NaN
# batteryCrankParamVP                                         NaN
# batteryCrankParamTT                                         NaN
# batteryCrankParamV0                                         NaN
# batteryVoltageMaxOn                                         NaN
# batteryVoltageMinOn                                         NaN
# batteryVoltageMaxOff                                        NaN
# batteryVoltageMinOff                                        NaN
# batteryVoltageOnAverage                                     NaN
# engineLoadMax                                               NaN
# engineLoadAverage                                           NaN
# rpmMax                                                      NaN
# rpmAverage                                                  NaN
# gpsSpeedAverage                                             NaN
# vssMax                                                      NaN
# vssAverage                                                  NaN
# tcuTemperatureMin                                           NaN
# tcuTemperatureMax                                           NaN
# tcuTemperatureAverage                                       NaN
# coolantMin                                                  NaN
# coolantMax                                                  NaN
# coolantAverage                                              NaN
# packetStartLocal                                            NaN
# tripStartLocal                                              NaN
# milIndicator                                                NaN
# monitorsNotReady                                            NaN
# imei                                                   60DF5417
# gatewayTs                                                   NaN
# diagnosticTroubleCodeData                                   NaN
# diagnosticPidData                                           NaN
# iwrapVer                                                 1.9.20
# sourceSystem                                                CDP
# configVer                                                   1.1
# oemName                                                     HUM
# unitType                                                      0
# cpVer                                                  7.50.1.9
# igpsVer                                                   1.3.7
# messageType                                        Notification
# pomVer                                                      1.0
# headerVer                                                    V6
# timestamp                                                     0
# deviceType                                              InDrive
# visorVer                                                 1.4.35
# transactionId              53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                         60DF5417
# subOrganization                                             HUM
# organization                                                HUM
# operation                                          Notification

# %%
d['data']
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
d1 = d['data']

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/50943  1553519835
# 1   https://github.com/pandas-dev/pandas/issues/50942  1553517151
# 2     https://github.com/pandas-dev/pandas/pull/50940  1553151547
# 3     https://github.com/pandas-dev/pandas/pull/50939  1552937053
# 4     https://github.com/pandas-dev/pandas/pull/50938  1552789803
# 5   https://github.com/pandas-dev/pandas/issues/50937  1552621344
# 6     https://github.com/pandas-dev/pandas/pull/50936  1552541307
# 7     https://github.com/pandas-dev/pandas/pull/50934  1552162193
# 8   https://github.com/pandas-dev/pandas/issues/50933  1552105672
# 9     https://github.com/pandas-dev/pandas/pull/50932  1552052798
# 10    https://github.com/pandas-dev/pandas/pull/50930  1551978927
# 11  https://github.com/pandas-dev/pandas/issues/50929  1551958144
# 12    https://github.com/pandas-dev/pandas/pull/50928  1551949728
# 13    https://github.com/pandas-dev/pandas/pull/50927  1551905761
# 14    https://github.com/pandas-dev/pandas/pull/50926  1551902169
# 15  https://github.com/pandas-dev/pandas/issues/50923  1551812846
# 16    https://github.com/pandas-dev/pandas/pull/50922  1551800028
# 17    https://github.com/pandas-dev/pandas/pull/50921  1551795461
# 18  https://github.com/pandas-dev/pandas/issues/50920  1551793418
# 19    https://github.com/pandas-dev/pandas/pull/50919  1551753471
# 20    https://github.com/pandas-dev/pandas/pull/50918  1551640156
# 21    https://github.com/pandas-dev/pandas/pull/50917  1551639591
# 22    https://github.com/pandas-dev/pandas/pull/50916  1551638558
# 23    https://github.com/pandas-dev/pandas/pull/50915  1551599318
# 24    https://github.com/pandas-dev/pandas/pull/50914  1551581124
# 25    https://github.com/pandas-dev/pandas/pull/50913  1551566586
# 26    https://github.com/pandas-dev/pandas/pull/50912  1551545552
# 27    https://github.com/pandas-dev/pandas/pull/50909  1551487063
# 28  https://github.com/pandas-dev/pandas/issues/50907  1551446031
# 29  https://github.com/pandas-dev/pandas/issues/50906  1551431872
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85IWVVU   50943
# 1    I_kwDOAA0YD85cmMpf   50942
# 2   PR_kwDOAA0YD85IVHKr   50940
# 3   PR_kwDOAA0YD85IUYod   50939
# 4   PR_kwDOAA0YD85IT4w7   50938
# 5    I_kwDOAA0YD85cix8g   50937
# 6   PR_kwDOAA0YD85ITDjB   50936
# 7   PR_kwDOAA0YD85IR1dL   50934
# 8    I_kwDOAA0YD85cg0DI   50933
# 9   PR_kwDOAA0YD85IRgRF   50932
# 10  PR_kwDOAA0YD85IRTRI   50930
# 11   I_kwDOAA0YD85cgQCA   50929
# 12  PR_kwDOAA0YD85IRNqM   50928
# 13  PR_kwDOAA0YD85IRFEe   50927
# 14  PR_kwDOAA0YD85IREZi   50926
# 15   I_kwDOAA0YD85cfsju   50923
# 16  PR_kwDOAA0YD85IQxeN   50922
# 17  PR_kwDOAA0YD85IQwmc   50921
# 18   I_kwDOAA0YD85cfn0K   50920
# 19  PR_kwDOAA0YD85IQo4h   50919
# 20  PR_kwDOAA0YD85IQS5M   50918
# 21  PR_kwDOAA0YD85IQSw2   50917
# 22  PR_kwDOAA0YD85IQShi   50916
# 23  PR_kwDOAA0YD85IQKjH   50915
# 24  PR_kwDOAA0YD85IQGdm   50914
# 25  PR_kwDOAA0YD85IQDYg   50913
# 26  PR_kwDOAA0YD85IP-1U   50912
# 27  PR_kwDOAA0YD85IPybY   50909
# 28   I_kwDOAA0YD85ceTAP   50907
# 29   I_kwDOAA0YD85cePjA   50906
#
#                                                 title  ... closed_at  \
# 0   Backport PR #50941 on branch 1.5.x (CI set LD_...  ...       NaT
# 1   BUG: empty slice assignment raises if datetime...  ...       NaT
# 2   DEPR: move NumericIndex._engine_type and .infe...  ...       NaT
# 3   Datetime parsing (PDEP-4): allow mixture of IS...  ...       NaT
# 4     Resolved duplicate issue by updating obj object  ...       NaT
# 5   BUG: query(engine='numexpr') not work correctl...  ...       NaT
# 6                             fixing dark mode styles  ...       NaT
# 7               CI: Adjust test to fix wheel builders  ...       NaT
# 8   BUG: `maybe_get_tz` raises `pytz.exceptions.Un...  ...       NaT
# 9   DEPR: move NumericIndex._convert_tolerance to ...  ...       NaT
# 10  BUG/PERF: Series(index=MultiIndex).rename losi...  ...       NaT
# 11  DOC: broken links in the "See also" section fo...  ...       NaT
# 12  ENH: support min/max/sum for pyarrow duration ...  ...       NaT
# 13         ENH: support cumsum with pyarrow durations  ...       NaT
# 14  API: Harmonize dtype for index levels for Seri...  ...       NaT
# 15  BUG:  Various pandas.api.types.is_*_dtype func...  ...       NaT
# 16  Rename .github/workflows/wheels.yml to config.yml  ...       NaT
# 17                                         cirlcle.ci  ...       NaT
# 18  REGR: SeriesGroupBy.value_counts failure on Wi...  ...       NaT
# 19                             Circleci project setup  ...       NaT
# 20  ENH: Optimize replace to avoid copying when no...  ...       NaT
# 21   ENH: Make shallow copy for align nocopy with CoW  ...       NaT
# 22       ENH: Add test for asfreq CoW when doing noop  ...       NaT
# 23  CLN: Use np.random.RandomState instead of tm.R...  ...       NaT
# 24            REF: standardize reso-return in parsing  ...       NaT
# 25    REF: Define methods on resample non-dynamically  ...       NaT
# 26  Changes how the latest version is taken from a...  ...       NaT
# 27  DEPR: casting strings to float in to_datetime ...  ...       NaT
# 28                   API: parsing Timestamp("2014Q2")  ...       NaT
# 29  BUG: when inner/outer-joining dataframes with ...  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0         CONTRIBUTOR                NaN    0.0
# 1                NONE                NaN    NaN
# 2         CONTRIBUTOR                NaN    0.0
# 3              MEMBER                NaN    0.0
# 4         CONTRIBUTOR                NaN    0.0
# 5                NONE                NaN    NaN
# 6                NONE                NaN    0.0
# 7              MEMBER                NaN    0.0
# 8                NONE                NaN    NaN
# 9         CONTRIBUTOR                NaN    0.0
# 10        CONTRIBUTOR                NaN    0.0
# 11        CONTRIBUTOR                NaN    NaN
# 12             MEMBER                NaN    0.0
# 13             MEMBER                NaN    0.0
# 14        CONTRIBUTOR                NaN    0.0
# 15        CONTRIBUTOR                NaN    NaN
# 16               NONE                NaN    0.0
# 17               NONE                NaN    0.0
# 18             MEMBER                NaN    NaN
# 19               NONE                NaN    0.0
# 20             MEMBER                NaN    0.0
# 21             MEMBER                NaN    0.0
# 22             MEMBER                NaN    0.0
# 23             MEMBER                NaN    0.0
# 24             MEMBER                NaN    0.0
# 25             MEMBER                NaN    0.0
# 26               NONE                NaN    0.0
# 27             MEMBER                NaN    0.0
# 28             MEMBER                NaN    NaN
# 29               NONE                NaN    NaN
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                 NaN
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5                                                 NaN
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8                                                 NaN
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28                                                NaN
# 29                                                NaN
#
#                                                  body  \
# 0   Backport PR #50941: CI set LD_PRELOAD in circl...
# 1   ### Pandas version checks\n\n- [X] I have chec...
# 2   Moves`_engine_type` & `inferred_type` from `Nu...
# 3   - [ ] closes #50411 (Replace xxxx with the Git...
# 4   - [x] closes #50845 \r\n- [ ] [Tests added and...
# 5   ### Pandas version checks\n\n- [X] I have chec...
# 6   Signed-off-by: Anushka Bishnoi <anushkabishnoi...
# 7   - [ ] closes #50898 (Replace xxxx with the Git...
# 8   ### Pandas version checks\n\n- [X] I have chec...
# 9   Moves`_convert_tolerance` from `NumericIndex`t...
# 10  - [x] closes #21055\r\n- [x] [Tests added and ...
# 11  ### Pandas version checks\n\n- [X] I have chec...
# 12  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 13                                     fixes 8 xfails
# 14  Currently the levels of the index the sparse s...
# 15  ### Pandas version checks\n\n- [X] I have chec...
# 16  - [x] closes #xxxx (Replace xxxx with the GitH...
# 17  - [x] closes #xxxx (Replace xxxx with the GitH...
# 18  Ref: https://github.com/pandas-dev/pandas/pull...
# 19  - [x] closes #xxxx (Replace xxxx with the GitH...
# 20  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 21  xref https://github.com/pandas-dev/pandas/pull...
# 22  xref https://github.com/pandas-dev/pandas/issu...
# 23                                               None
# 24  Moving towards getting reso inference working ...
# 25  - [ ] closes #49001 (Replace xxxx with the Git...
# 26  - [ ] closes Better management of releases in ...
# 27  - [x] closes #50735 (Replace xxxx with the Git...
# 28  ```python\r\n>>> pd.Timestamp("2014Q2")\r\nTim...
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
import requests

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50941',
#   'id': 1553238844,
#   'node_id': 'PR_kwDOAA0YD85IVZr6',
#   'number': 50941,
#   'title': 'CI set LD_PRELOAD in circleci job',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-23T14:54:11Z',
#   'updated_at': '2023-01-23T16:11:14Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50941',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50941',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50941.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50941.patch',
#    'merged_at': None},
#   'body': 'circle CI job is failing, let\'s see if this fixes anything\r\n\r\n```python-traceback\r\n=================================== FAILURES ===================================\r\n______________________________ test_scikit_learn _______________________________\r\n[gw2] linux -- Python 3.8.15 /home/circleci/miniconda3/envs/pandas-dev/bin/python3.8\r\n\r\n    def test_scikit_learn():\r\n    \r\n>       sklearn = import_module("sklearn")  # noqa:F841\r\n\r\npandas/tests/test_downstream.py:158: \r\n_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ \r\npandas/tests/test_downstream.py:27: in import_module\r\n    return importlib.import_module(name)\r\n../miniconda3/envs/pandas-dev/lib/python3.8/importlib/__init__.py:127: in import_module\r\n    return _bootstrap._gcd_import(name[level:], package, level)\r\n<frozen importlib._bootstrap>:1014: in _gcd_import\r\n    ???\r\n<frozen importlib._bootstrap>:991: in _find_and_load\r\n    ???\r\n<frozen importlib._bootstrap>:975: in _find_and_load_unlocked\r\n    ???\r\n<frozen importlib._bootstrap>:671: in _load_unlocked\r\n    ???\r\n<frozen importlib._bootstrap_external>:843: in exec_module\r\n    ???\r\n<frozen importlib._bootstrap>:219: in _call_with_frames_removed\r\n    ???\r\n../miniconda3/envs/pandas-dev/lib/python3.8/site-packages/sklearn/__init__.py:83: in <module>\r\n    from .utils._show_versions import show_versions\r\n_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ \r\n\r\n    """\r\n    Utility methods to print system info for debugging\r\n    \r\n    adapted from :func:`pandas.show_versions`\r\n    """\r\n    # License: BSD 3 clause\r\n    \r\n    import platform\r\n    import sys\r\n    from ..utils.fixes import threadpool_info\r\n    from .. import __version__\r\n    \r\n    \r\n>   from ._openmp_helpers import _openmp_parallelism_enabled\r\nE   ImportError: /home/circleci/miniconda3/envs/pandas-dev/lib/python3.8/site-packages/sklearn/utils/../../../../libgomp.so.1: cannot allocate memory in static TLS block\r\n\r\n../miniconda3/envs/pandas-dev/lib/python3.8/site-packages/sklearn/utils/_show_versions.py:14: ImportError\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50940',
#   'id': 1553151547,
#   'node_id': 'PR_kwDOAA0YD85IVHKr',
#   'number': 50940,
#   'title': 'DEPR: move NumericIndex._engine_type and .inferred_type to Index',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-01-23T14:00:09Z',
#   'updated_at': '2023-01-23T17:05:48Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50940',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50940',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50940.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50940.patch',
#    'merged_at': None},
#   'body': 'Moves`_engine_type` & `inferred_type` from `NumericIndex`to `Index` in preparation to remove `NumericIndex` and include numpy int/uint/float64 in the base `Index`.\r\n\r\nxref #42717.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50939',
#   'id': 1552937053,
#   'node_id': 'PR_kwDOAA0YD85IUYod',
#   'number': 50939,
#   'title': 'Datetime parsing (PDEP-4): allow mixture of ISO formatted strings',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-23T11:30:23Z',
#   'updated_at': '2023-01-23T15:56:49Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50939',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50939',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50939.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50939.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #50411 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50938',
#   'id': 1552789803,
#   'node_id': 'PR_kwDOAA0YD85IT4w7',
#   'number': 50938,
#   'title': 'Resolved duplicate issue by updating obj object',
#   'user': {'login': 'asadullahnaeem',
#    'id': 48176260,
#    'node_id': 'MDQ6VXNlcjQ4MTc2MjYw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48176260?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asadullahnaeem',
#    'html_url': 'https://github.com/asadullahnaeem',
#    'followers_url': 'https://api.github.com/users/asadullahnaeem/followers',
#    'following_url': 'https://api.github.com/users/asadullahnaeem/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/asadullahnaeem/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/asadullahnaeem/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/asadullahnaeem/subscriptions',
#    'organizations_url': 'https://api.github.com/users/asadullahnaeem/orgs',
#    'repos_url': 'https://api.github.com/users/asadullahnaeem/repos',
#    'events_url': 'https://api.github.com/users/asadullahnaeem/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/asadullahnaeem/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-23T09:44:10Z',
#   'updated_at': '2023-01-23T09:44:10Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50938',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50938',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50938.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50938.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50845 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50937',
#   'id': 1552621344,
#   'node_id': 'I_kwDOAA0YD85cix8g',
#   'number': 50937,
#   'title': "BUG: query(engine='numexpr') not work correctly when column name is 'max' or 'min'.",
#   'user': {'login': 'bsdfan',
#    'id': 1309101,
#    'node_id': 'MDQ6VXNlcjEzMDkxMDE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1309101?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bsdfan',
#    'html_url': 'https://github.com/bsdfan',
#    'followers_url': 'https://api.github.com/users/bsdfan/followers',
#    'following_url': 'https://api.github.com/users/bsdfan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bsdfan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bsdfan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bsdfan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bsdfan/orgs',
#    'repos_url': 'https://api.github.com/users/bsdfan/repos',
#    'events_url': 'https://api.github.com/users/bsdfan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bsdfan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1631985267,
#     'node_id': 'MDU6TGFiZWwxNjMxOTg1MjY3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/expressions',
#     'name': 'expressions',
#     'color': 'f3afff',
#     'default': False,
#     'description': 'pd.eval, query'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-01-23T07:14:25Z',
#   'updated_at': '2023-01-23T17:01:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ndf = pd.DataFrame({\'max\': [1, 2, 3]})\r\ndf.query(\'max == 1\', engine=\'numexpr\')\r\n# Empty DataFrame\r\ndf.query(\'max < 2\', engine=\'numexpr\')\r\n# TypeError: \'<\' not supported between instances of \'function\' and \'int\'\n```\n\n\n### Issue Description\n\nDataFrame.query(engine=\'numexpr\') does not work correctly when column name is \'max\' or \'min\'.\r\n\r\nBecause numexpr seems to have \'max\' and \'min\' as built-in reduction function though it is not officially documented, \r\nhttps://github.com/pydata/numexpr/issues/120\r\n\r\nThese keywords should be checked in pandas like \'sum\' and \'prod\'.\r\nSo REDUCTIONS in pandas/core/computation/ops.py may need to be updated.\n\n### Expected Behavior\n\nNumExprClobberingError should be raised.\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame({\'max\': [1, 2, 3]})\r\ndf.query(\'max == 1\', engine=\'numexpr\')\r\n# NumExprClobberingError: Variables in expression "(max) == (1)" overlap with builtins: (\'max\')\r\n```\n\n### Installed Versions\n\n<details>\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\npython           : 3.9.16.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : Japanese_Japan.932\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.22.3\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 66.1.1\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.8.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : 0.56.3\r\nnumexpr          : 2.8.4\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 10.0.1\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.7.3\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n```\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50936',
#   'id': 1552541307,
#   'node_id': 'PR_kwDOAA0YD85ITDjB',
#   'number': 50936,
#   'title': 'fixing dark mode styles',
#   'user': {'login': 'anushkabishnoi',
#    'id': 97040192,
#    'node_id': 'U_kgDOBci3QA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97040192?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anushkabishnoi',
#    'html_url': 'https://github.com/anushkabishnoi',
#    'followers_url': 'https://api.github.com/users/anushkabishnoi/followers',
#    'following_url': 'https://api.github.com/users/anushkabishnoi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/anushkabishnoi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/anushkabishnoi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/anushkabishnoi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/anushkabishnoi/orgs',
#    'repos_url': 'https://api.github.com/users/anushkabishnoi/repos',
#    'events_url': 'https://api.github.com/users/anushkabishnoi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/anushkabishnoi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-23T05:28:22Z',
#   'updated_at': '2023-01-23T05:28:22Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50936',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50936',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50936.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50936.patch',
#    'merged_at': None},
#   'body': 'Signed-off-by: Anushka Bishnoi <anushkabishnoi9@gmail.com>\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50934',
#   'id': 1552162193,
#   'node_id': 'PR_kwDOAA0YD85IR1dL',
#   'number': 50934,
#   'title': 'CI: Adjust test to fix wheel builders',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-01-22T15:32:45Z',
#   'updated_at': '2023-01-22T17:31:38Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50934',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50934',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50934.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50934.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #50898 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50933',
#   'id': 1552105672,
#   'node_id': 'I_kwDOAA0YD85cg0DI',
#   'number': 50933,
#   'title': 'BUG: `maybe_get_tz` raises `pytz.exceptions.UnknownTimeZoneError` when building a timezone from a filename',
#   'user': {'login': 'daureg',
#    'id': 19685,
#    'node_id': 'MDQ6VXNlcjE5Njg1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19685?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daureg',
#    'html_url': 'https://github.com/daureg',
#    'followers_url': 'https://api.github.com/users/daureg/followers',
#    'following_url': 'https://api.github.com/users/daureg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/daureg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/daureg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/daureg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/daureg/orgs',
#    'repos_url': 'https://api.github.com/users/daureg/repos',
#    'events_url': 'https://api.github.com/users/daureg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/daureg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-01-22T12:51:24Z',
#   'updated_at': '2023-01-23T16:02:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ns = pd.Series(pd.DatetimeIndex(["2018-09-15 01:30:00"]))\r\nprint(s.dt.tz_localize("Europe/Berlin"))\r\nprint(s.dt.tz_localize(":/usr/share/zoneinfo/Europe/Berlin"))\n```\n\n\n### Issue Description\n\nWhile the first call to `tz_localize` works, the second fails with the traceback below. I experienced this problem after setting my `TZ` environment variable to `:/etc/locatime` to avoid [unnecessary system calls from glibc](https://blog.packagecloud.io/set-environment-variable-save-thousands-of-system-calls), as specified in [the `timezone` man page](https://manpages.ubuntu.com/manpages/jammy/en/man3/timezone.3.html):\r\n> The second format [of the **TZ** environment variable] specifies that the timezone information should be read from a file:\r\n>           :[filespec]\r\n\r\n```python-traceback\r\nTraceback (most recent call last):\r\n  File "/home/glefalher/pytztz/t.py", line 5, in <module>\r\n    print(s.dt.tz_localize(":/usr/share/zoneinfo/Europe/Berlin"))\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/accessor.py", line 96, in f\r\n    return self._delegate_method(name, *args, **kwargs)\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/indexes/accessors.py", line 123, in _delegate_method\r\n    result = method(*args, **kwargs)\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py", line 276, in tz_localize\r\n    arr = self._data.tz_localize(tz, ambiguous, nonexistent)\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py", line 86, in method\r\n    return meth(self, *args, **kwargs)\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py", line 1038, in tz_localize\r\n    tz = timezones.maybe_get_tz(tz)\r\n  File "pandas/_libs/tslibs/timezones.pyx", line 145, in pandas._libs.tslibs.timezones.maybe_get_tz\r\n  File "pandas/_libs/tslibs/timezones.pyx", line 170, in pandas._libs.tslibs.timezones.maybe_get_tz\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pytz/__init__.py", line 188, in timezone\r\n    raise UnknownTimeZoneError(zone)\r\npytz.exceptions.UnknownTimeZoneError: \':/usr/share/zoneinfo/Europe/Berlin\'\r\n```\n\n### Expected Behavior\n\nBoth lines should produce to the same results, but honestly I\'m not sure if pandas or pytz should take care of that 🤔 \n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\n```\r\npython           : 3.9.16.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.15.0-58-generic\r\nVersion          : #64-Ubuntu SMP Thu Jan 5 11:43:13 UTC 2023\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.24.1\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 66.1.1\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\n ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50932',
#   'id': 1552052798,
#   'node_id': 'PR_kwDOAA0YD85IRgRF',
#   'number': 50932,
#   'title': 'DEPR: move NumericIndex._convert_tolerance to Index',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-22T09:18:19Z',
#   'updated_at': '2023-01-23T15:42:14Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50932',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50932',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50932.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50932.patch',
#    'merged_at': None},
#   'body': 'Moves`_convert_tolerance` from `NumericIndex`to `Index` in preparation to remove `NumericIndex` and include numpy int/uint/float64 in the base `Index`.\r\n\r\nxref #42717.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50930',
#   'id': 1551978927,
#   'node_id': 'PR_kwDOAA0YD85IRTRI',
#   'number': 50930,
#   'title': 'BUG/PERF: Series(index=MultiIndex).rename losing EA dtypes',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-22T02:04:09Z',
#   'updated_at': '2023-01-22T02:04:09Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50930',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50930',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50930.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50930.patch',
#    'merged_at': None},
#   'body': '- [x] closes #21055\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst` file if fixing a bug or adding a new feature.\r\n\r\n\r\n`Series(index=MultiIndex).rename` loses EA dtypes: \r\n\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\nlev0 = pd.Index(np.arange(1000), dtype="Int64").astype("category")\r\nlev1 = pd.Index(np.arange(1000), dtype="Int64")\r\n\r\nmi = pd.MultiIndex.from_product([lev0, lev1], names=["A", "B"])\r\nser1 = pd.Series(1, index=mi)\r\nser2 = ser1.rename({10: 11}, level=1)\r\n\r\nprint(ser2.index.dtypes)\r\n```\r\n\r\nmain:\r\n```\r\nA       int64\r\nB       int64\r\ndtype: object\r\n```\r\n\r\nPR:\r\n```\r\nA    category\r\nB       Int64\r\ndtype: object\r\n```\r\n\r\nPerf improves as well:\r\n\r\n```\r\n%timeit ser1.rename({10: 11}, level=1)\r\n\r\n1.25 s ± 52.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)  -> main\r\n350 ms ± 8.29 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)  -> PR\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50929',
#   'id': 1551958144,
#   'node_id': 'I_kwDOAA0YD85cgQCA',
#   'number': 50929,
#   'title': 'DOC: broken links in the "See also" section for pandas.core.window.rolling.Rolling.rank',
#   'user': {'login': 'partev',
#    'id': 23830955,
#    'node_id': 'MDQ6VXNlcjIzODMwOTU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23830955?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/partev',
#    'html_url': 'https://github.com/partev',
#    'followers_url': 'https://api.github.com/users/partev/followers',
#    'following_url': 'https://api.github.com/users/partev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/partev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/partev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/partev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/partev/orgs',
#    'repos_url': 'https://api.github.com/users/partev/repos',
#    'events_url': 'https://api.github.com/users/partev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/partev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-22T00:12:38Z',
#   'updated_at': '2023-01-22T00:12:38Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\n"See also" section in the Documentation for Rolling.rank has broken links.\r\n\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.core.window.rolling.Rolling.rank.html\r\n\r\n![Screenshot 2023-01-21 19 07 07](https://user-images.githubusercontent.com/23830955/213894895-3dfa9eba-1d95-485b-a652-d2119866dbc6.png)\r\n\n\n### Documentation problem\n\nThe links to "Series.rolling", "DataFrame.rolling", "Series.rank" and "DataFrame.rank" are broken.\n\n### Suggested fix for documentation\n\nthose broken links need to link to:\r\n\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.Series.rolling.html\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.rolling.html\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.Series.rank.html\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.rank.html',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50928',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50928/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50928/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50928/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50928',
#   'id': 1551949728,
#   'node_id': 'PR_kwDOAA0YD85IRNqM',
#   'number': 50928,
#   'title': 'ENH: support min/max/sum for pyarrow duration dtypes',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
# ...
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-20T21:45:36Z',
#   'updated_at': '2023-01-20T21:45:36Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50909',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50909',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50909.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50909.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50735 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50909/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50909/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50907',
#   'id': 1551446031,
#   'node_id': 'I_kwDOAA0YD85ceTAP',
#   'number': 50907,
#   'title': 'API: parsing Timestamp("2014Q2")',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-20T21:01:02Z',
#   'updated_at': '2023-01-20T21:10:16Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '```python\r\n>>> pd.Timestamp("2014Q2")\r\nTimestamp(\'2014-04-01 00:00:00\')\r\n```\r\n\r\nIt isn\'t obvious to me that we should allow this.  We could reasonably raise and tell users to call pd.Period instead.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50906',
#   'id': 1551431872,
#   'node_id': 'I_kwDOAA0YD85cePjA',
#   'number': 50906,
#   'title': 'BUG: when inner/outer-joining dataframes with categorical MultiIndex, the output index dtype depends on row ordering',
#   'user': {'login': 'mcrumiller',
#    'id': 1896992,
#    'node_id': 'MDQ6VXNlcjE4OTY5OTI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1896992?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcrumiller',
#    'html_url': 'https://github.com/mcrumiller',
#    'followers_url': 'https://api.github.com/users/mcrumiller/followers',
#    'following_url': 'https://api.github.com/users/mcrumiller/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mcrumiller/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mcrumiller/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mcrumiller/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mcrumiller/orgs',
#    'repos_url': 'https://api.github.com/users/mcrumiller/repos',
#    'events_url': 'https://api.github.com/users/mcrumiller/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mcrumiller/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'},
#    {'id': 986278782,
#     'node_id': 'MDU6TGFiZWw5ODYyNzg3ODI=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Tests',
#     'name': 'Needs Tests',
#     'color': 'cdea3c',
#     'default': False,
#     'description': 'Unit test(s) needed to prevent regressions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-01-20T20:46:41Z',
#   'updated_at': '2023-01-22T19:04:33Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\n# a simple dataframe with column `c` = 0, 1, 2\r\ndf1 = pd.DataFrame({\r\n    \'a\': pd.Categorical([0, 1, 2]),\r\n    \'b\': pd.Categorical([0, 1, 2]),\r\n    \'c\': [0, 1, 2]\r\n}).set_index([\'a\', \'b\'])\r\n\r\n# identical\r\ndf2 = pd.DataFrame({\r\n    \'a\': pd.Categorical([0, 1, 2]),\r\n    \'b\': pd.Categorical([0, 1, 2]),\r\n    \'d\': [0, 1, 2]\r\n}).set_index([\'a\', \'b\'])\r\n\r\n# identical but different row ordering\r\ndf3 = pd.DataFrame({\r\n    \'a\': pd.Categorical([0, 2, 1]),\r\n    \'b\': pd.Categorical([0, 2, 1]),\r\n    \'e\': [0, 2, 1]\r\n}).set_index([\'a\', \'b\'])\r\n\r\n# a normal join returns `category` if indexes are identical\r\ndf1.join(df2).index.dtypes  # category, category\r\ndf1.join(df2, how="outer").index.dtypes # category, category\r\n\r\n# if index ordering is different, dtype of index depends on join type:\r\ndf1.join(df3).index.dtypes               # category, category\r\ndf1.join(df3, how="outer").index.dtypes  # int64, int64\r\ndf1.join(df3, how="inner").index.dtypes  # int64, int64\r\ndf1.join(df3, how="left").index.dtypes   # category, category\r\ndf1.join(df3, how="right").index.dtypes  # category, category\n```\n\n\n### Issue Description\n\nIf two dataframes both are multi-indexed with categorical levels, then performing a `join` operation results in the dtype of the index being un-categorized depending on the ordering of the input. If the indexes match ordering, the output is categorical; if the indexes have different ordering, the output is cast to the underlying categorical dtype.\n\n### Expected Behavior\n\nAll joins shown above should produce categorical index levels.\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\npython           : 3.9.13.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 140 Stepping 1, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.23.4\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.1\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : 7.2.0\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.9.5\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.6.2\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 10.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : 1.4.43\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n```\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50904',
#   'id': 1551410879,
#   'node_id': 'PR_kwDOAA0YD85IPi3S',
#   'number': 50904,
#   'title': 'Split orient',
#   'user': {'login': 'labibdotc',
#    'id': 98433990,
#    'node_id': 'U_kgDOBd37xg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98433990?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/labibdotc',
#    'html_url': 'https://github.com/labibdotc',
#    'followers_url': 'https://api.github.com/users/labibdotc/followers',
#    'following_url': 'https://api.github.com/users/labibdotc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/labibdotc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/labibdotc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/labibdotc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/labibdotc/orgs',
#    'repos_url': 'https://api.github.com/users/labibdotc/repos',
#    'events_url': 'https://api.github.com/users/labibdotc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/labibdotc/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-20T20:27:05Z',
#   'updated_at': '2023-01-20T20:27:05Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50904',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50904',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50904.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50904.patch',
#    'merged_at': None},
#   'body': '- Closes #50456\r\n- xFail for mark split deprecated.\r\n- All [code checks passed].\r\n- Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst`\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1)
# Out:
# 30

# %%
data1[0]['user']['id']
# Out:
# 33491632

# %%
for i in range(len(data1)):
    print(data1[0]['user']['id'])
# Out:
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50941',
#   'id': 1553238844,
#   'node_id': 'PR_kwDOAA0YD85IVZr6',
#   'number': 50941,
#   'title': 'CI set LD_PRELOAD in circleci job',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-23T14:54:11Z',
#   'updated_at': '2023-01-23T16:11:14Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50941',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50941',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50941.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50941.patch',
#    'merged_at': None},
#   'body': 'circle CI job is failing, let\'s see if this fixes anything\r\n\r\n```python-traceback\r\n=================================== FAILURES ===================================\r\n______________________________ test_scikit_learn _______________________________\r\n[gw2] linux -- Python 3.8.15 /home/circleci/miniconda3/envs/pandas-dev/bin/python3.8\r\n\r\n    def test_scikit_learn():\r\n    \r\n>       sklearn = import_module("sklearn")  # noqa:F841\r\n\r\npandas/tests/test_downstream.py:158: \r\n_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ \r\npandas/tests/test_downstream.py:27: in import_module\r\n    return importlib.import_module(name)\r\n../miniconda3/envs/pandas-dev/lib/python3.8/importlib/__init__.py:127: in import_module\r\n    return _bootstrap._gcd_import(name[level:], package, level)\r\n<frozen importlib._bootstrap>:1014: in _gcd_import\r\n    ???\r\n<frozen importlib._bootstrap>:991: in _find_and_load\r\n    ???\r\n<frozen importlib._bootstrap>:975: in _find_and_load_unlocked\r\n    ???\r\n<frozen importlib._bootstrap>:671: in _load_unlocked\r\n    ???\r\n<frozen importlib._bootstrap_external>:843: in exec_module\r\n    ???\r\n<frozen importlib._bootstrap>:219: in _call_with_frames_removed\r\n    ???\r\n../miniconda3/envs/pandas-dev/lib/python3.8/site-packages/sklearn/__init__.py:83: in <module>\r\n    from .utils._show_versions import show_versions\r\n_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ \r\n\r\n    """\r\n    Utility methods to print system info for debugging\r\n    \r\n    adapted from :func:`pandas.show_versions`\r\n    """\r\n    # License: BSD 3 clause\r\n    \r\n    import platform\r\n    import sys\r\n    from ..utils.fixes import threadpool_info\r\n    from .. import __version__\r\n    \r\n    \r\n>   from ._openmp_helpers import _openmp_parallelism_enabled\r\nE   ImportError: /home/circleci/miniconda3/envs/pandas-dev/lib/python3.8/site-packages/sklearn/utils/../../../../libgomp.so.1: cannot allocate memory in static TLS block\r\n\r\n../miniconda3/envs/pandas-dev/lib/python3.8/site-packages/sklearn/utils/_show_versions.py:14: ImportError\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50941/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50940',
#   'id': 1553151547,
#   'node_id': 'PR_kwDOAA0YD85IVHKr',
#   'number': 50940,
#   'title': 'DEPR: move NumericIndex._engine_type and .inferred_type to Index',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-01-23T14:00:09Z',
#   'updated_at': '2023-01-23T17:05:48Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50940',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50940',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50940.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50940.patch',
#    'merged_at': None},
#   'body': 'Moves`_engine_type` & `inferred_type` from `NumericIndex`to `Index` in preparation to remove `NumericIndex` and include numpy int/uint/float64 in the base `Index`.\r\n\r\nxref #42717.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50940/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50939',
#   'id': 1552937053,
#   'node_id': 'PR_kwDOAA0YD85IUYod',
#   'number': 50939,
#   'title': 'Datetime parsing (PDEP-4): allow mixture of ISO formatted strings',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-23T11:30:23Z',
#   'updated_at': '2023-01-23T15:56:49Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50939',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50939',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50939.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50939.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #50411 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50939/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50938',
#   'id': 1552789803,
#   'node_id': 'PR_kwDOAA0YD85IT4w7',
#   'number': 50938,
#   'title': 'Resolved duplicate issue by updating obj object',
#   'user': {'login': 'asadullahnaeem',
#    'id': 48176260,
#    'node_id': 'MDQ6VXNlcjQ4MTc2MjYw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48176260?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asadullahnaeem',
#    'html_url': 'https://github.com/asadullahnaeem',
#    'followers_url': 'https://api.github.com/users/asadullahnaeem/followers',
#    'following_url': 'https://api.github.com/users/asadullahnaeem/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/asadullahnaeem/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/asadullahnaeem/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/asadullahnaeem/subscriptions',
#    'organizations_url': 'https://api.github.com/users/asadullahnaeem/orgs',
#    'repos_url': 'https://api.github.com/users/asadullahnaeem/repos',
#    'events_url': 'https://api.github.com/users/asadullahnaeem/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/asadullahnaeem/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-23T09:44:10Z',
#   'updated_at': '2023-01-23T09:44:10Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50938',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50938',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50938.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50938.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50845 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50937',
#   'id': 1552621344,
#   'node_id': 'I_kwDOAA0YD85cix8g',
#   'number': 50937,
#   'title': "BUG: query(engine='numexpr') not work correctly when column name is 'max' or 'min'.",
#   'user': {'login': 'bsdfan',
#    'id': 1309101,
#    'node_id': 'MDQ6VXNlcjEzMDkxMDE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1309101?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bsdfan',
#    'html_url': 'https://github.com/bsdfan',
#    'followers_url': 'https://api.github.com/users/bsdfan/followers',
#    'following_url': 'https://api.github.com/users/bsdfan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bsdfan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bsdfan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bsdfan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bsdfan/orgs',
#    'repos_url': 'https://api.github.com/users/bsdfan/repos',
#    'events_url': 'https://api.github.com/users/bsdfan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bsdfan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1631985267,
#     'node_id': 'MDU6TGFiZWwxNjMxOTg1MjY3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/expressions',
#     'name': 'expressions',
#     'color': 'f3afff',
#     'default': False,
#     'description': 'pd.eval, query'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-01-23T07:14:25Z',
#   'updated_at': '2023-01-23T17:01:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ndf = pd.DataFrame({\'max\': [1, 2, 3]})\r\ndf.query(\'max == 1\', engine=\'numexpr\')\r\n# Empty DataFrame\r\ndf.query(\'max < 2\', engine=\'numexpr\')\r\n# TypeError: \'<\' not supported between instances of \'function\' and \'int\'\n```\n\n\n### Issue Description\n\nDataFrame.query(engine=\'numexpr\') does not work correctly when column name is \'max\' or \'min\'.\r\n\r\nBecause numexpr seems to have \'max\' and \'min\' as built-in reduction function though it is not officially documented, \r\nhttps://github.com/pydata/numexpr/issues/120\r\n\r\nThese keywords should be checked in pandas like \'sum\' and \'prod\'.\r\nSo REDUCTIONS in pandas/core/computation/ops.py may need to be updated.\n\n### Expected Behavior\n\nNumExprClobberingError should be raised.\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame({\'max\': [1, 2, 3]})\r\ndf.query(\'max == 1\', engine=\'numexpr\')\r\n# NumExprClobberingError: Variables in expression "(max) == (1)" overlap with builtins: (\'max\')\r\n```\n\n### Installed Versions\n\n<details>\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\npython           : 3.9.16.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : Japanese_Japan.932\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.22.3\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 66.1.1\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.8.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : 0.56.3\r\nnumexpr          : 2.8.4\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 10.0.1\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.7.3\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n```\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50937/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50936',
#   'id': 1552541307,
#   'node_id': 'PR_kwDOAA0YD85ITDjB',
#   'number': 50936,
#   'title': 'fixing dark mode styles',
#   'user': {'login': 'anushkabishnoi',
#    'id': 97040192,
#    'node_id': 'U_kgDOBci3QA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97040192?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anushkabishnoi',
#    'html_url': 'https://github.com/anushkabishnoi',
#    'followers_url': 'https://api.github.com/users/anushkabishnoi/followers',
#    'following_url': 'https://api.github.com/users/anushkabishnoi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/anushkabishnoi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/anushkabishnoi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/anushkabishnoi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/anushkabishnoi/orgs',
#    'repos_url': 'https://api.github.com/users/anushkabishnoi/repos',
#    'events_url': 'https://api.github.com/users/anushkabishnoi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/anushkabishnoi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-23T05:28:22Z',
#   'updated_at': '2023-01-23T05:28:22Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50936',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50936',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50936.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50936.patch',
#    'merged_at': None},
#   'body': 'Signed-off-by: Anushka Bishnoi <anushkabishnoi9@gmail.com>\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50936/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50934',
#   'id': 1552162193,
#   'node_id': 'PR_kwDOAA0YD85IR1dL',
#   'number': 50934,
#   'title': 'CI: Adjust test to fix wheel builders',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-01-22T15:32:45Z',
#   'updated_at': '2023-01-22T17:31:38Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50934',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50934',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50934.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50934.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #50898 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50934/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50933',
#   'id': 1552105672,
#   'node_id': 'I_kwDOAA0YD85cg0DI',
#   'number': 50933,
#   'title': 'BUG: `maybe_get_tz` raises `pytz.exceptions.UnknownTimeZoneError` when building a timezone from a filename',
#   'user': {'login': 'daureg',
#    'id': 19685,
#    'node_id': 'MDQ6VXNlcjE5Njg1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19685?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daureg',
#    'html_url': 'https://github.com/daureg',
#    'followers_url': 'https://api.github.com/users/daureg/followers',
#    'following_url': 'https://api.github.com/users/daureg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/daureg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/daureg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/daureg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/daureg/orgs',
#    'repos_url': 'https://api.github.com/users/daureg/repos',
#    'events_url': 'https://api.github.com/users/daureg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/daureg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-01-22T12:51:24Z',
#   'updated_at': '2023-01-23T16:02:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ns = pd.Series(pd.DatetimeIndex(["2018-09-15 01:30:00"]))\r\nprint(s.dt.tz_localize("Europe/Berlin"))\r\nprint(s.dt.tz_localize(":/usr/share/zoneinfo/Europe/Berlin"))\n```\n\n\n### Issue Description\n\nWhile the first call to `tz_localize` works, the second fails with the traceback below. I experienced this problem after setting my `TZ` environment variable to `:/etc/locatime` to avoid [unnecessary system calls from glibc](https://blog.packagecloud.io/set-environment-variable-save-thousands-of-system-calls), as specified in [the `timezone` man page](https://manpages.ubuntu.com/manpages/jammy/en/man3/timezone.3.html):\r\n> The second format [of the **TZ** environment variable] specifies that the timezone information should be read from a file:\r\n>           :[filespec]\r\n\r\n```python-traceback\r\nTraceback (most recent call last):\r\n  File "/home/glefalher/pytztz/t.py", line 5, in <module>\r\n    print(s.dt.tz_localize(":/usr/share/zoneinfo/Europe/Berlin"))\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/accessor.py", line 96, in f\r\n    return self._delegate_method(name, *args, **kwargs)\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/indexes/accessors.py", line 123, in _delegate_method\r\n    result = method(*args, **kwargs)\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py", line 276, in tz_localize\r\n    arr = self._data.tz_localize(tz, ambiguous, nonexistent)\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py", line 86, in method\r\n    return meth(self, *args, **kwargs)\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py", line 1038, in tz_localize\r\n    tz = timezones.maybe_get_tz(tz)\r\n  File "pandas/_libs/tslibs/timezones.pyx", line 145, in pandas._libs.tslibs.timezones.maybe_get_tz\r\n  File "pandas/_libs/tslibs/timezones.pyx", line 170, in pandas._libs.tslibs.timezones.maybe_get_tz\r\n  File "/home/glefalher/pytztz/lib/python3.9/site-packages/pytz/__init__.py", line 188, in timezone\r\n    raise UnknownTimeZoneError(zone)\r\npytz.exceptions.UnknownTimeZoneError: \':/usr/share/zoneinfo/Europe/Berlin\'\r\n```\n\n### Expected Behavior\n\nBoth lines should produce to the same results, but honestly I\'m not sure if pandas or pytz should take care of that 🤔 \n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\n```\r\npython           : 3.9.16.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.15.0-58-generic\r\nVersion          : #64-Ubuntu SMP Thu Jan 5 11:43:13 UTC 2023\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.24.1\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 66.1.1\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\n ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50933/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50932',
#   'id': 1552052798,
#   'node_id': 'PR_kwDOAA0YD85IRgRF',
#   'number': 50932,
#   'title': 'DEPR: move NumericIndex._convert_tolerance to Index',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-22T09:18:19Z',
#   'updated_at': '2023-01-23T15:42:14Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50932',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50932',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50932.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50932.patch',
#    'merged_at': None},
#   'body': 'Moves`_convert_tolerance` from `NumericIndex`to `Index` in preparation to remove `NumericIndex` and include numpy int/uint/float64 in the base `Index`.\r\n\r\nxref #42717.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50932/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50930',
#   'id': 1551978927,
#   'node_id': 'PR_kwDOAA0YD85IRTRI',
#   'number': 50930,
#   'title': 'BUG/PERF: Series(index=MultiIndex).rename losing EA dtypes',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-22T02:04:09Z',
#   'updated_at': '2023-01-22T02:04:09Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50930',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50930',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50930.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50930.patch',
#    'merged_at': None},
#   'body': '- [x] closes #21055\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst` file if fixing a bug or adding a new feature.\r\n\r\n\r\n`Series(index=MultiIndex).rename` loses EA dtypes: \r\n\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\nlev0 = pd.Index(np.arange(1000), dtype="Int64").astype("category")\r\nlev1 = pd.Index(np.arange(1000), dtype="Int64")\r\n\r\nmi = pd.MultiIndex.from_product([lev0, lev1], names=["A", "B"])\r\nser1 = pd.Series(1, index=mi)\r\nser2 = ser1.rename({10: 11}, level=1)\r\n\r\nprint(ser2.index.dtypes)\r\n```\r\n\r\nmain:\r\n```\r\nA       int64\r\nB       int64\r\ndtype: object\r\n```\r\n\r\nPR:\r\n```\r\nA    category\r\nB       Int64\r\ndtype: object\r\n```\r\n\r\nPerf improves as well:\r\n\r\n```\r\n%timeit ser1.rename({10: 11}, level=1)\r\n\r\n1.25 s ± 52.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)  -> main\r\n350 ms ± 8.29 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)  -> PR\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50930/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50929',
#   'id': 1551958144,
#   'node_id': 'I_kwDOAA0YD85cgQCA',
#   'number': 50929,
#   'title': 'DOC: broken links in the "See also" section for pandas.core.window.rolling.Rolling.rank',
#   'user': {'login': 'partev',
#    'id': 23830955,
#    'node_id': 'MDQ6VXNlcjIzODMwOTU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23830955?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/partev',
#    'html_url': 'https://github.com/partev',
#    'followers_url': 'https://api.github.com/users/partev/followers',
#    'following_url': 'https://api.github.com/users/partev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/partev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/partev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/partev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/partev/orgs',
#    'repos_url': 'https://api.github.com/users/partev/repos',
#    'events_url': 'https://api.github.com/users/partev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/partev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-22T00:12:38Z',
#   'updated_at': '2023-01-22T00:12:38Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\n"See also" section in the Documentation for Rolling.rank has broken links.\r\n\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.core.window.rolling.Rolling.rank.html\r\n\r\n![Screenshot 2023-01-21 19 07 07](https://user-images.githubusercontent.com/23830955/213894895-3dfa9eba-1d95-485b-a652-d2119866dbc6.png)\r\n\n\n### Documentation problem\n\nThe links to "Series.rolling", "DataFrame.rolling", "Series.rank" and "DataFrame.rank" are broken.\n\n### Suggested fix for documentation\n\nthose broken links need to link to:\r\n\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.Series.rolling.html\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.rolling.html\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.Series.rank.html\r\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.rank.html',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50929/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50928',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50928/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50928/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50928/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50928',
#   'id': 1551949728,
#   'node_id': 'PR_kwDOAA0YD85IRNqM',
#   'number': 50928,
#   'title': 'ENH: support min/max/sum for pyarrow duration dtypes',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
# ...
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-20T21:45:36Z',
#   'updated_at': '2023-01-20T21:45:36Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50909',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50909',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50909.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50909.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50735 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50909/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50909/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50907',
#   'id': 1551446031,
#   'node_id': 'I_kwDOAA0YD85ceTAP',
#   'number': 50907,
#   'title': 'API: parsing Timestamp("2014Q2")',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-20T21:01:02Z',
#   'updated_at': '2023-01-20T21:10:16Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '```python\r\n>>> pd.Timestamp("2014Q2")\r\nTimestamp(\'2014-04-01 00:00:00\')\r\n```\r\n\r\nIt isn\'t obvious to me that we should allow this.  We could reasonably raise and tell users to call pd.Period instead.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50907/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50906',
#   'id': 1551431872,
#   'node_id': 'I_kwDOAA0YD85cePjA',
#   'number': 50906,
#   'title': 'BUG: when inner/outer-joining dataframes with categorical MultiIndex, the output index dtype depends on row ordering',
#   'user': {'login': 'mcrumiller',
#    'id': 1896992,
#    'node_id': 'MDQ6VXNlcjE4OTY5OTI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1896992?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mcrumiller',
#    'html_url': 'https://github.com/mcrumiller',
#    'followers_url': 'https://api.github.com/users/mcrumiller/followers',
#    'following_url': 'https://api.github.com/users/mcrumiller/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mcrumiller/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mcrumiller/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mcrumiller/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mcrumiller/orgs',
#    'repos_url': 'https://api.github.com/users/mcrumiller/repos',
#    'events_url': 'https://api.github.com/users/mcrumiller/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mcrumiller/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'},
#    {'id': 986278782,
#     'node_id': 'MDU6TGFiZWw5ODYyNzg3ODI=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Tests',
#     'name': 'Needs Tests',
#     'color': 'cdea3c',
#     'default': False,
#     'description': 'Unit test(s) needed to prevent regressions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-01-20T20:46:41Z',
#   'updated_at': '2023-01-22T19:04:33Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\n# a simple dataframe with column `c` = 0, 1, 2\r\ndf1 = pd.DataFrame({\r\n    \'a\': pd.Categorical([0, 1, 2]),\r\n    \'b\': pd.Categorical([0, 1, 2]),\r\n    \'c\': [0, 1, 2]\r\n}).set_index([\'a\', \'b\'])\r\n\r\n# identical\r\ndf2 = pd.DataFrame({\r\n    \'a\': pd.Categorical([0, 1, 2]),\r\n    \'b\': pd.Categorical([0, 1, 2]),\r\n    \'d\': [0, 1, 2]\r\n}).set_index([\'a\', \'b\'])\r\n\r\n# identical but different row ordering\r\ndf3 = pd.DataFrame({\r\n    \'a\': pd.Categorical([0, 2, 1]),\r\n    \'b\': pd.Categorical([0, 2, 1]),\r\n    \'e\': [0, 2, 1]\r\n}).set_index([\'a\', \'b\'])\r\n\r\n# a normal join returns `category` if indexes are identical\r\ndf1.join(df2).index.dtypes  # category, category\r\ndf1.join(df2, how="outer").index.dtypes # category, category\r\n\r\n# if index ordering is different, dtype of index depends on join type:\r\ndf1.join(df3).index.dtypes               # category, category\r\ndf1.join(df3, how="outer").index.dtypes  # int64, int64\r\ndf1.join(df3, how="inner").index.dtypes  # int64, int64\r\ndf1.join(df3, how="left").index.dtypes   # category, category\r\ndf1.join(df3, how="right").index.dtypes  # category, category\n```\n\n\n### Issue Description\n\nIf two dataframes both are multi-indexed with categorical levels, then performing a `join` operation results in the dtype of the index being un-categorized depending on the ordering of the input. If the indexes match ordering, the output is categorical; if the indexes have different ordering, the output is cast to the underlying categorical dtype.\n\n### Expected Behavior\n\nAll joins shown above should produce categorical index levels.\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\npython           : 3.9.13.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 140 Stepping 1, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.23.4\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.1\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : 7.2.0\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.9.5\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.6.2\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 10.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : 1.4.43\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n```\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50906/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50904',
#   'id': 1551410879,
#   'node_id': 'PR_kwDOAA0YD85IPi3S',
#   'number': 50904,
#   'title': 'Split orient',
#   'user': {'login': 'labibdotc',
#    'id': 98433990,
#    'node_id': 'U_kgDOBd37xg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98433990?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/labibdotc',
#    'html_url': 'https://github.com/labibdotc',
#    'followers_url': 'https://api.github.com/users/labibdotc/followers',
#    'following_url': 'https://api.github.com/users/labibdotc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/labibdotc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/labibdotc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/labibdotc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/labibdotc/orgs',
#    'repos_url': 'https://api.github.com/users/labibdotc/repos',
#    'events_url': 'https://api.github.com/users/labibdotc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/labibdotc/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-20T20:27:05Z',
#   'updated_at': '2023-01-20T20:27:05Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50904',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50904',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50904.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50904.patch',
#    'merged_at': None},
#   'body': '- Closes #50456\r\n- xFail for mark split deprecated.\r\n- All [code checks passed].\r\n- Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst`\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50904/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
pd.DataFrame(data1, columns=['id','url','repository_url','labels_url','comments_url','events_url'])
# Out:
#             id                                                url  \
# 0   1553238844  https://api.github.com/repos/pandas-dev/pandas...
# 1   1553151547  https://api.github.com/repos/pandas-dev/pandas...
# 2   1552937053  https://api.github.com/repos/pandas-dev/pandas...
# 3   1552789803  https://api.github.com/repos/pandas-dev/pandas...
# 4   1552621344  https://api.github.com/repos/pandas-dev/pandas...
# 5   1552541307  https://api.github.com/repos/pandas-dev/pandas...
# 6   1552162193  https://api.github.com/repos/pandas-dev/pandas...
# 7   1552105672  https://api.github.com/repos/pandas-dev/pandas...
# 8   1552052798  https://api.github.com/repos/pandas-dev/pandas...
# 9   1551978927  https://api.github.com/repos/pandas-dev/pandas...
# 10  1551958144  https://api.github.com/repos/pandas-dev/pandas...
# 11  1551949728  https://api.github.com/repos/pandas-dev/pandas...
# 12  1551905761  https://api.github.com/repos/pandas-dev/pandas...
# 13  1551902169  https://api.github.com/repos/pandas-dev/pandas...
# 14  1551812846  https://api.github.com/repos/pandas-dev/pandas...
# 15  1551800028  https://api.github.com/repos/pandas-dev/pandas...
# 16  1551795461  https://api.github.com/repos/pandas-dev/pandas...
# 17  1551793418  https://api.github.com/repos/pandas-dev/pandas...
# 18  1551753471  https://api.github.com/repos/pandas-dev/pandas...
# 19  1551640156  https://api.github.com/repos/pandas-dev/pandas...
# 20  1551639591  https://api.github.com/repos/pandas-dev/pandas...
# 21  1551638558  https://api.github.com/repos/pandas-dev/pandas...
# 22  1551599318  https://api.github.com/repos/pandas-dev/pandas...
# 23  1551581124  https://api.github.com/repos/pandas-dev/pandas...
# 24  1551566586  https://api.github.com/repos/pandas-dev/pandas...
# 25  1551545552  https://api.github.com/repos/pandas-dev/pandas...
# 26  1551487063  https://api.github.com/repos/pandas-dev/pandas...
# 27  1551446031  https://api.github.com/repos/pandas-dev/pandas...
# 28  1551431872  https://api.github.com/repos/pandas-dev/pandas...
# 29  1551410879  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
df1 =pd.DataFrame(data1, columns=['id','url','repository_url','labels_url','comments_url','events_url'])

# %%
df1.to_csv('json_read1.csv')

# %%
import json

# %%
df = pd.DataFrame(data1)

# %%
df.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
df['user']
# Out:
# 0     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 1     {'login': 'topper-123', 'id': 26364415, 'node_...
# 2     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 3     {'login': 'asadullahnaeem', 'id': 48176260, 'n...
# 4     {'login': 'bsdfan', 'id': 1309101, 'node_id': ...
# 5     {'login': 'anushkabishnoi', 'id': 97040192, 'n...
# 6     {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 7     {'login': 'daureg', 'id': 19685, 'node_id': 'M...
# 8     {'login': 'topper-123', 'id': 26364415, 'node_...
# 9     {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 10    {'login': 'partev', 'id': 23830955, 'node_id':...
# 11    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 12    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 13    {'login': 'topper-123', 'id': 26364415, 'node_...
# 14    {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 15    {'login': 'Hexx333', 'id': 116751160, 'node_id...
# 16    {'login': 'Hexx333', 'id': 116751160, 'node_id...
# 17    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 18    {'login': 'Hexx333', 'id': 116751160, 'node_id...
# 19    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 20    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 21    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 22    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 23    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 24    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 25    {'login': 'JustinAmstadt', 'id': 100241650, 'n...
# 26    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 27    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 28    {'login': 'mcrumiller', 'id': 1896992, 'node_i...
# 29    {'login': 'labibdotc', 'id': 98433990, 'node_i...
# Name: user, dtype: object

# %%
user_df =pd.json_normalize(df['user'])

# %%
final_df= pd.concat([df1, user_df], axis=1)

# %%
final_df.to_csv('finally.csv')
