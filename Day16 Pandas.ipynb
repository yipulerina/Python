# %%
import pandas as pd

# %%
df = pd.read_excel('Book1.xlsx')
df.head()
# Out:
#    House Age (years)  Distance to Station (meters)  Price per Square Foot  \
# 0               32.0                      84.87882                   75.8
# 1               19.5                     306.59470                   84.4
# 2               13.3                     561.98450                   94.6
# 3               13.3                     561.98450                  109.6
# 4                5.0                     390.56840                   86.2
#
#    Unnamed: 3            Sum
# 0         NaN           Mean
# 1         NaN         Median
# 2         NaN           Mode
# 3         NaN  St. Deviation
# 4         NaN       Variance

# %%
df1 = pd.read_csv(r'C:\Users\lerin\Downloads\Data\locations.csv')
df1.head()
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
# 2   3                1                                           NaN
# 3   4                1                                    wheelchair
# 4   5                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
# 4  Provides fixed 8% short term loans to eligible...   NaN
#
# ...

# %%
df2= pd.read_csv(r'C:\Users\lerin\Downloads\Data\taxonomy.csv')
df2.head()
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0         101                Emergency       NaN             NaN
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv(r'C:\Users\lerin\Downloads\Data\taxonomy.csv', header = None)
# Out:
#              0                             1       2                     3
# 0          101                     Emergency     NaN                   NaN
# 1       101-01             Disaster Response     101             Emergency
# 2       101-02                Emergency Cash     101             Emergency
# 3    101-02-01             Help Pay for Food  101-02        Emergency Cash
# 4    101-02-02       Help Pay for Healthcare  101-02        Emergency Cash
# ..         ...                           ...     ...                   ...
# 285  111-01-07              Workplace Rights  111-01  Advocacy & Legal Aid
# 286     111-02                     Mediation     111                 Legal
# 287     111-03                        Notary     111                 Legal
# 288     111-04                Representation     111                 Legal
# 289     111-05  Translation & Interpretation     111                 Legal
#
# [290 rows x 4 columns]

# %%
pd.read_csv(r'C:\Users\lerin\Downloads\Data\taxonomy.csv',names=['serial no.','status','digit','sfds'])
# Out:
#     serial no.                        status   digit                  sfds
# 0          101                     Emergency     NaN                   NaN
# 1       101-01             Disaster Response     101             Emergency
# 2       101-02                Emergency Cash     101             Emergency
# 3    101-02-01             Help Pay for Food  101-02        Emergency Cash
# 4    101-02-02       Help Pay for Healthcare  101-02        Emergency Cash
# ..         ...                           ...     ...                   ...
# 285  111-01-07              Workplace Rights  111-01  Advocacy & Legal Aid
# 286     111-02                     Mediation     111                 Legal
# 287     111-03                        Notary     111                 Legal
# 288     111-04                Representation     111                 Legal
# 289     111-05  Translation & Interpretation     111                 Legal
#
# [290 rows x 4 columns]

# %%
pd.read_csv(r'C:\Users\lerin\Downloads\Data\taxonomy.csv',names=['serial no.','status','digit','sfds','sgsdg','agdg'])
# Out:
#     serial no.                        status   digit                  sfds  \
# 0          101                     Emergency     NaN                   NaN
# 1       101-01             Disaster Response     101             Emergency
# 2       101-02                Emergency Cash     101             Emergency
# 3    101-02-01             Help Pay for Food  101-02        Emergency Cash
# 4    101-02-02       Help Pay for Healthcare  101-02        Emergency Cash
# ..         ...                           ...     ...                   ...
# 285  111-01-07              Workplace Rights  111-01  Advocacy & Legal Aid
# 286     111-02                     Mediation     111                 Legal
# 287     111-03                        Notary     111                 Legal
# 288     111-04                Representation     111                 Legal
# 289     111-05  Translation & Interpretation     111                 Legal
#
#      sgsdg  agdg
# 0      NaN   NaN
# 1      NaN   NaN
# ...

# %%
pd.read_csv(r'C:\Users\lerin\Downloads\Data\taxonomy.csv',names=['serial no.','status'])
# Out:
#                                        serial no.                status
# 101       Emergency                           NaN                   NaN
# 101-01    Disaster Response                   101             Emergency
# 101-02    Emergency Cash                      101             Emergency
# 101-02-01 Help Pay for Food                101-02        Emergency Cash
# 101-02-02 Help Pay for Healthcare          101-02        Emergency Cash
# ...                                           ...                   ...
# 111-01-07 Workplace Rights                 111-01  Advocacy & Legal Aid
# 111-02    Mediation                           111                 Legal
# 111-03    Notary                              111                 Legal
# 111-04    Representation                      111                 Legal
# 111-05    Translation & Interpretation        111                 Legal
#
# [290 rows x 2 columns]

# %%
pd.read_csv(r'C:\Users\lerin\Downloads\Data\taxonomy.csv')
# Out:
#                                        101@Emergency@@
# 0               101-01@Disaster Response@101@Emergency
# 1                  101-02@Emergency Cash@101@Emergency
# 2    101-02-01@Help Pay for Food@101-02@Emergency Cash
# 3    101-02-02@Help Pay for Healthcare@101-02@Emerg...
# 4    101-02-03@Help Pay for Housing@101-02@Emergenc...
# ..                                                 ...
# 284  111-01-07@Workplace Rights@111-01@Advocacy & L...
# 285                         111-02@Mediation@111@Legal
# 286                            111-03@Notary@111@Legal
# 287                    111-04@Representation@111@Legal
# 288      111-05@Translation & Interpretation@111@Legal
#
# [289 rows x 1 columns]

# %%
pd.read_csv(r'C:\Users\lerin\Downloads\Data\taxonomy.csv', sep='@')
# Out:
#            101                     Emergency Unnamed: 2            Unnamed: 3
# 0       101-01             Disaster Response        101             Emergency
# 1       101-02                Emergency Cash        101             Emergency
# 2    101-02-01             Help Pay for Food     101-02        Emergency Cash
# 3    101-02-02       Help Pay for Healthcare     101-02        Emergency Cash
# 4    101-02-03          Help Pay for Housing     101-02        Emergency Cash
# ..         ...                           ...        ...                   ...
# 284  111-01-07              Workplace Rights     111-01  Advocacy & Legal Aid
# 285     111-02                     Mediation        111                 Legal
# 286     111-03                        Notary        111                 Legal
# 287     111-04                Representation        111                 Legal
# 288     111-05  Translation & Interpretation        111                 Legal
#
# [289 rows x 4 columns]

# %%
pd.read_csv(r'C:\Users\lerin\Downloads\Data\locations.csv')
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv(r'C:\Users\lerin\Downloads\Data\locations.csv', sep='|')
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking| ramp| restroom| wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking| wheelchair
# 6    7                2       ramp| restroom| disabled_parking| wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp| restroom| wheelchair
# 9   10                3  elevator| tape_braille| ramp| restroom| disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv(r'C:\Users\lerin\Downloads\Data\contacts.csv', skiprows=[1,5])
# Out:
#    id  location_id  organization_id  service_id                name  \
# 0   2            1              NaN         NaN  Christina Gonzalez
# 1   3            2              NaN         NaN        Brenda Brown
# 2   4            3              NaN         NaN  Howard Lader, LCSW
# 3   6            5              NaN         NaN           Joe Bloom
# 4   7            6              NaN         NaN         Peter Olson
# 5   8            6              NaN         NaN        Bart Charlow
# 6   9            7              NaN         NaN        Bart Charlow
#
#                                              title  email  department
# 0                                  Center Director    NaN         NaN
# 1                 Director, Second Career Services    NaN         NaN
# 2                  Manager, Senior Peer Counseling    NaN         NaN
# 3  Financial Empowerment Programs Program Director    NaN         NaN
# 4                            Little House Director    NaN         NaN
# ...

# %%
df4 = pd.read_csv(r'C:\Users\lerin\Downloads\Data\services.csv')
df4.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df4.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df4.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %%
df4.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
a = df4['funding_sources']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df4[['name','funding_sources']]
# Out:
#                                     name  \
# 0        Fair Oaks Adult Activity Center
# 1       Second Career Employment Program
# 2                 Senior Peer Counseling
# 3               Family Visitation Center
# 4      Economic Self-Sufficiency Program
# 5   Little House Recreational Activities
# 6       Rosener House Adult Day Services
# 7         Meals on Wheels - South County
# 8                       Fair Oaks Branch
# 9                           Main Library
# 10                       Schaberg Branch
# 11                          Project Read
# 12                 Redwood Shores Branch
# 13                    Redwood City Corps
# 14           Adult Rehabilitation Center
# 15                       Sunnyvale Corps
# 16     South San Francisco Citadel Corps
# 17                         Project Smile
# 18         San Mateo Free Medical Clinic
# 19             Service with blank fields
# 20       Service for Admin Test Location
# 21                       Passport Photos
# ...

# %%
df5 = df4[['name','funding_sources']]
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
 type(df4[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel(r'C:\Users\lerin\Downloads\Data\LUSID Excel - Manage Orders.xlsx',sheet_name='Allocations')
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.read_excel(r'C:\Users\lerin\Downloads\Data\LUSID Excel - Manage Orders.xlsx')

# %%
df.keys()
# Out:
# Index(['House Age (years)', 'Distance to Station (meters)',
#        'Price per Square Foot', 'Unnamed: 3', 'Sum'],
#       dtype='object')

# %%
df = pd.ExcelFile(r'C:\Users\lerin\Downloads\Data\LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    pd.read_excel(r'C:\Users\lerin\Downloads\Data\LUSID Excel - Manage Orders.xlsx',sheet_name=i )

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
